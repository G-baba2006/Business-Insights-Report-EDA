# %%
import pandas as pd
import numpy as np
data = {
'Channel':[
'Facebook',
'Instagram',
'Google Ads',
'Email',
'YouTube',
'Facebook',
'Google Ads',
'Instagram'
],
'Cost':[
10000,
15000,
20000,
5000,
18000,
12000,
22000,
14000
],
'Revenue':[
25000,
32000,
50000,
12000,
35000,
28000,
55000,
30000
],
'Impressions':[
100000,
150000,
200000,
60000,
180000,
120000,
210000,
140000
],
'Clicks':[
5000,
7000,
9000,
3000,
8000,
5500,
9500,
7200
],
'Conversions':[
400,
650,
950,
250,
700,
450,
1000,
680
]
}
df=pd.DataFrame(data)
df.to_csv(
'marketing_campaign.csv',
index=False
)
df.head()
# Out:
#       Channel   Cost  Revenue  Impressions  Clicks  Conversions
# 0    Facebook  10000    25000       100000    5000          400
# 1   Instagram  15000    32000       150000    7000          650
# 2  Google Ads  20000    50000       200000    9000          950
# 3       Email   5000    12000        60000    3000          250
# 4     YouTube  18000    35000       180000    8000          700

# %%
df
# Out:
#       Channel   Cost  Revenue  Impressions  Clicks  Conversions
# 0    Facebook  10000    25000       100000    5000          400
# 1   Instagram  15000    32000       150000    7000          650
# 2  Google Ads  20000    50000       200000    9000          950
# 3       Email   5000    12000        60000    3000          250
# 4     YouTube  18000    35000       180000    8000          700
# 5    Facebook  12000    28000       120000    5500          450
# 6  Google Ads  22000    55000       210000    9500         1000
# 7   Instagram  14000    30000       140000    7200          680

# %%
df['ROI']=(
(df['Revenue']-
df['Cost'])
/
df['Cost']
)*100
df
# Out:
#       Channel   Cost  Revenue  Impressions  Clicks  Conversions         ROI
# 0    Facebook  10000    25000       100000    5000          400  150.000000
# 1   Instagram  15000    32000       150000    7000          650  113.333333
# 2  Google Ads  20000    50000       200000    9000          950  150.000000
# 3       Email   5000    12000        60000    3000          250  140.000000
# 4     YouTube  18000    35000       180000    8000          700   94.444444
# 5    Facebook  12000    28000       120000    5500          450  133.333333
# 6  Google Ads  22000    55000       210000    9500         1000  150.000000
# 7   Instagram  14000    30000       140000    7200          680  114.285714

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(
x='Channel',
y='Revenue',
data=df
)
plt.show()

# %%
sns.barplot(
x='Channel',
y='ROI',
data=df
)
plt.show()

# %%
funnel=[
df['Impressions'].sum(),
df['Clicks'].sum(),
df['Conversions'].sum()
]
labels=[
'Impressions',
'Clicks',
'Conversions'
]
plt.bar(
labels,
funnel
)
plt.show()

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
import pandas as pd
data = {
'Channel':['Facebook','Instagram','Google Ads','Email','YouTube'],
'Cost':[10000,15000,20000,5000,18000],
'Revenue':[25000,32000,50000,12000,35000],
'Impressions':[100000,150000,200000,60000,180000],
'Clicks':[5000,7000,9000,3000,8000],
'Conversions':[400,650,950,250,700]
}
df=pd.DataFrame(data)

df['ROI']=(
(df['Revenue']-df['Cost'])/
df['Cost']
)*100
df.to_csv(
'cleaned_marketing.csv',
index=False
)
print("File Created Successfully")
# Out:
# File Created Successfully

# %%
df[['Channel','Cost','Revenue','ROI']].sort_values(
'ROI',
ascending=False
)
# Out:
#       Channel   Cost  Revenue         ROI
# 0    Facebook  10000    25000  150.000000
# 2  Google Ads  20000    50000  150.000000
# 3       Email   5000    12000  140.000000
# 1   Instagram  15000    32000  113.333333
# 4     YouTube  18000    35000   94.444444
